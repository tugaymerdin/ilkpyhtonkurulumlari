# %% [markdown]
# Pyhton programlama dilince print komutu ekrandan kullancıya bilgi veren bir koddur. İGÜ İstka Siber Akademi Merkezi - 06.08.2024 Veri Yapıları ve Algoritma dersi ilk çıktısıdır.

# %%
print ("Merhaba, Avcılar!")
#print ekrana cikti veren bir koddur.
# Out:
# Merhaba, Avcılar!

# %%
import sys # import pyhton programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive baglantisi
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd  # BİZE KODUN CİKTİSİNİ DOSYA YOLU OLARAK VEREN KOD BLOGUDUR.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
